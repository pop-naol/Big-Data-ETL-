# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\Projects\Big Data\BG  Assignmnet\ASSIGNMNET\Data\extracted_raw.csv", low_memory=False)

print(df.shape)
# Out:
# (3068095, 139)

# %%
threshold = len(df) * 0.6
df = df.dropna(axis=1, thresh=threshold)

print("After column cleaning:", df.shape)
# Out:
# After column cleaning: (3068095, 18)

# %%
df = df.fillna(0)
# Out:
# Columns: ['31', '29', '0', '0.1', '2', '2.1', '0.2', '0.3', '0.4', '7', '1', '1.1', 'tcp', 'FIN', '-', '255', '255.1', '6']
# Dtypes: 31         int64
# 29         int64
# 0          int64
# 0.1        int64
# 2          int64
# 2.1      float64
# 0.2        int64
# 0.3        int64
# 0.4      float64
# 7          int64
# 1          int64
# 1.1        int64
# tcp       object
# FIN       object
# -         object
# 255      float64
# 255.1    float64
# 6        float64
# dtype: object

# %%
df.to_csv(r"D:\Projects\Big Data\BG  Assignmnet\ASSIGNMNET\Data\transformed_data.csv", index=False)
