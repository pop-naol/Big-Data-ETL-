# %%
import pandas as pd
import os

# %%
file_path = "Data\cybersecurity_attack.csv"
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\naols\AppData\Local\Temp\ipykernel_22420\2027839478.py:1: SyntaxWarning: invalid escape sequence '\c'
#   file_path = "Data\cybersecurity_attack.csv"

# %%
df = pd.read_csv(file_path, low_memory=False)

print("Shape:", df.shape)
df.head()

# %%
print(df.info())
print(df.isnull().sum().sort_values(ascending=False).head(20))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3068095 entries, 0 to 3068094
# Columns: 139 entries, 59.166.0.0 to 4
# dtypes: float64(107), int64(10), object(22)
# memory usage: 3.2+ GB
# None
# Unnamed: 38      3042834
# Unnamed: 37      2959845
# smtp             2800000
# 1424250009       2800000
# 3.943843         2800000
# 1424250009.1     2800000
# 149.171.126.7    2800000
# 0.000473         2800000
# 0.00059          2800000
# 8                2800000
# 18               2800000
# 4                2800000
# 42               2800000
# 0.000117         2800000
# 1422136554       2800000
# 3572668484       2800000
# 722              2800000
# 456.043567       2800000
# 15.530109        2800000
# 52               2800000
# dtype: int64

# %%
df.to_csv(r"D:\Projects\Big Data\BG  Assignmnet\ASSIGNMNET\Data\extracted_raw.csv", index=False)
